# %%
import os
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

_ = load_dotenv(find_dotenv())

chat_model = ChatGroq(model = "llama-3.1-8b-instant")

prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}.")

chain = prompt | chat_model | StrOutputParser()

# %%
response = chain.invoke({"topic" : "computers"})

response
# Out:
# 'Why did the computer go to the doctor? \n\nBecause it had a virus.'

# %%
for s in chain.stream({"topic" : "computers"}):
    print(s, end="", flush=True)
# Out:
# Why did the computer go to the doctor?
#
# Because it had a virus.

# %%
chain.batch([{"topic": "computers"}, {"topic": "cats"}, {"topic": "space"}])
# Out:
# ['Why did the computer go to the doctor?\n\nBecause it had a virus.',
#  'Why did the cat join a band? \n\nBecause it wanted to be the purr-cussionist.',
#  'Why did the astronaut break up with his girlfriend before going to Mars?\n\nBecause he needed space.']
